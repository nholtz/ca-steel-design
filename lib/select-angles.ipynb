# %%
from sst import SST
sst = SST()

# %%
wl = sst.section_tables(['L'],'Mass')

def myfunc0(shape):
    return shape.A >= 1080.

s = sst.select_rows(wl,myfunc0)
s[['Dsg','Avl','T','A']]
# Out:
#                        Dsg  Avl      T        A
# Dsg
# L89x89x6.4      L89x89x6.4  NaN   6.35   1090.0
# L102x76x6.4    L102x76x6.4  NaN   6.35   1090.0
# L64x64x9.5      L64x64x9.5  NaN   9.53   1120.0
# L76x51x9.5      L76x51x9.5  NaN   9.53   1120.0
# L76x76x7.9      L76x76x7.9  NaN   7.94   1150.0
# L89x64x7.9      L89x64x7.9  NaN   7.94   1150.0
# L102x89x6.4    L102x89x6.4  NaN   6.35   1170.0
# L76x64x9.5      L76x64x9.5  NaN   9.53   1240.0
# L89x76x7.9      L89x76x7.9  NaN   7.94   1250.0
# L127x76x6.4    L127x76x6.4  NaN   6.35   1250.0
# L102x102x6.4  L102x102x6.4  NaN   6.35   1260.0
# L127x89x6.4    L127x89x6.4  NaN   6.35   1330.0
# L102x76x7.9    L102x76x7.9  NaN   7.94   1350.0
# L89x89x7.9      L89x89x7.9  NaN   7.94   1350.0
# L76x76x9.5      L76x76x9.5  NaN   9.53   1360.0
# L89x64x9.5      L89x64x9.5  NaN   9.53   1360.0
# L76x51x13        L76x51x13  NaN  12.70   1450.0
# L64x64x13        L64x64x13  NaN  12.70   1450.0
# ...
